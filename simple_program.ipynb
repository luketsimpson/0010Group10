# %% [markdown]
# ### A Simple Python Program

# %%
# Get user inputs
name = input("What's your name? ")
print("Enter 2 numbers and I will output the product")
number1 = int(input("Number 1: "))
number2 = int(input("Number 2: "))
print("Your name is: " + name + " and the product of your two numbers is: " + str(number1 * number2))
# Out:
# What's your name?  g
# Enter 2 numbers and I will output the product
# Number 1:  1
# Number 2:  1
# Your name is: g and the product of your two numbers is: 1
